# %%
import pandas as pd

# %%
store_sales = pd.read_csv('http://bit.ly/PMR-ch3') # Observations of total sales by week for two competing products at a chain of stores

# %%
store_sales.shape
# Out:
# (2080, 10)

# %%
store_sales.head()
# Out:
#    store_num  year  week  p1_sales  p2_sales  p1_price  p2_price  \
# 0      101.0   1.0   1.0     122.0     110.0      2.99      2.99
# 1      101.0   1.0   2.0     160.0      79.0      2.49      3.19
# 2      101.0   1.0   3.0     169.0      80.0      2.19      2.99
# 3      101.0   1.0   4.0     119.0     102.0      2.49      2.49
# 4      101.0   1.0   5.0     114.0     143.0      2.49      2.59
#
#    p1_promo  p2_promo country
# 0         0         1     USA
# 1         0         0     USA
# 2         0         0     USA
# 3         0         0     USA
# 4         0         1     USA

# %%
store_sales.dtypes
# Out:
# store_num    float64
# year         float64
# week         float64
# p1_sales     float64
# p2_sales     float64
# p1_price     float64
# p2_price     float64
# p1_promo       int64
# p2_promo       int64
# country       object
# dtype: object

# %%
type(store_sales.country[0])
# Out:
# str

# %%
store_sales.country = store_sales['country'].astype(pd.CategoricalDtype())
store_sales.country.head()
# Out:
# 0    USA
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# Name: country, dtype: category
# Categories (7, object): ['AUS', 'BRA', 'CHN', 'DEU', 'GBR', 'JPN', 'USA']

# %%
store_sales.dtypes
# Out:
# store_num     float64
# year          float64
# week          float64
# p1_sales      float64
# p2_sales      float64
# p1_price      float64
# p2_price      float64
# p1_promo        int64
# p2_promo        int64
# country      category
# dtype: object

# %%
store_sales.store_num = store_sales['store_num'].astype(pd.CategoricalDtype())
store_sales.store_num.head()
# Out:
# 0    101.0
# 1    101.0
# 2    101.0
# 3    101.0
# 4    101.0
# Name: store_num, dtype: category
# Categories (20, float64): [101.0, 102.0, 103.0, 104.0, ..., 117.0, 118.0, 119.0, 120.0]

# %%
store_sales.dtypes
# Out:
# store_num    category
# year          float64
# week          float64
# p1_sales      float64
# p2_sales      float64
# p1_price      float64
# p2_price      float64
# p1_promo        int64
# p2_promo        int64
# country      category
# dtype: object

# %%
store_sales.p1_promo.value_counts()
# Out:
# p1_promo
# 0    1871
# 1     209
# Name: count, dtype: int64

# %% [markdown]
# ## Functions to Summarize a Variable

# %% [markdown]
# ###groupby()

# %%
store_sales.groupby('store_num')
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fcd6f8c3790>
# <ipython-input-19-d75d694e6f3d>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   x = store_sales.groupby('store_num')

# %%
store_sales.groupby('store_num').p1_sales.mean()
# Out:
# <ipython-input-20-8062a9195605>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   store_sales.groupby('store_num').p1_sales.mean()
# store_num
# 101.0    133.500000
# 102.0    138.807692
# 103.0    132.682692
# 104.0    131.798077
# 105.0    135.480769
# 106.0    136.057692
# 107.0    138.980769
# 108.0    133.865385
# 109.0    134.096154
# 110.0    134.653846
# 111.0    134.278846
# 112.0    133.000000
# 113.0    134.855769
# 114.0    128.211538
# 115.0    130.923077
# 116.0    132.576923
# 117.0    135.375000
# 118.0    134.423077
# 119.0    132.336538
# 120.0    133.451923
# Name: p1_sales, dtype: float64

# %%
store_sales.groupby(['store_num', 'year']).p1_sales.mean()
# Out:
# <ipython-input-21-8e59ae59dcd8>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   store_sales.groupby(['store_num', 'year']).p1_sales.mean()
# store_num  year
# 101.0      1.0     132.538462
#            2.0     134.461538
# 102.0      1.0     139.692308
#            2.0     137.923077
# 103.0      1.0     130.557692
#            2.0     134.807692
# 104.0      1.0     127.653846
#            2.0     135.942308
# 105.0      1.0     136.000000
#            2.0     134.961538
# 106.0      1.0     135.653846
#            2.0     136.461538
# 107.0      1.0     139.615385
#            2.0     138.346154
# 108.0      1.0     136.230769
#            2.0     131.500000
# 109.0      1.0     130.557692
#            2.0     137.634615
# 110.0      1.0     130.961538
#            2.0     138.346154
# 111.0      1.0     136.461538
#            2.0     132.096154
# 112.0      1.0     130.500000
#            2.0     135.500000
# 113.0      1.0     135.384615
#            2.0     134.326923
# 114.0      1.0     124.519231
#            2.0     131.903846
# 115.0      1.0     130.788462
#            2.0     131.057692
# 116.0      1.0     132.884615
#            2.0     132.269231
# 117.0      1.0     134.134615
#            2.0     136.615385
# 118.0      1.0     129.519231
#            2.0     139.326923
# 119.0      1.0     137.134615
#            2.0     127.538462
# 120.0      1.0     136.019231
#            2.0     130.884615
# Name: p1_sales, dtype: float64

# %%
store_sales.groupby(['store_num', 'year']).p1_sales.mean().unstack()
# Out:
# <ipython-input-23-63a89ab5e231>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   store_sales.groupby(['store_num', 'year']).p1_sales.mean().unstack()
# year              1.0         2.0
# store_num
# 101.0      132.538462  134.461538
# 102.0      139.692308  137.923077
# 103.0      130.557692  134.807692
# 104.0      127.653846  135.942308
# 105.0      136.000000  134.961538
# 106.0      135.653846  136.461538
# 107.0      139.615385  138.346154
# 108.0      136.230769  131.500000
# 109.0      130.557692  137.634615
# 110.0      130.961538  138.346154
# 111.0      136.461538  132.096154
# 112.0      130.500000  135.500000
# 113.0      135.384615  134.326923
# 114.0      124.519231  131.903846
# 115.0      130.788462  131.057692
# 116.0      132.884615  132.269231
# 117.0      134.134615  136.615385
# 118.0      129.519231  139.326923
# 119.0      137.134615  127.538462
# 120.0      136.019231  130.884615

# %%
p1_sales_by_country = store_sales.groupby(['country']).p1_sales.sum()
p1_sales_by_country
# Out:
# <ipython-input-24-eb7ab15f4d64>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   p1_sales_by_country = store_sales.groupby(['country']).p1_sales.sum()
# country
# AUS    13980.0
# BRA    27857.0
# CHN    27642.0
# DEU    70323.0
# GBR    41915.0
# JPN    54817.0
# USA    42119.0
# Name: p1_sales, dtype: float64

# %% [markdown]
# ### Discrete Variables

# %%
store_sales.p1_price.value_counts()
# Out:
# p1_price
# 2.29    420
# 2.19    417
# 2.49    416
# 2.99    415
# 2.79    412
# Name: count, dtype: int64

# %%
p1_table_0 = store_sales.p1_price.value_counts()
p1_table_0
# Out:
# p1_price
# 2.29    420
# 2.19    417
# 2.49    416
# 2.99    415
# 2.79    412
# Name: count, dtype: int64

# %%
type(p1_table_0)
# Out:
# pandas.core.series.Series

# %%
p1_table_0.plot.bar()
# Out:
# <Axes: xlabel='p1_price'>

# %%
pd.crosstab(store_sales.p1_promo, store_sales.p1_price) # summarizes the relationship between categorical variables
# Out:
# p1_price  2.19  2.29  2.49  2.79  2.99
# p1_promo
# 0          371   380   378   371   371
# 1           46    40    38    41    44

# %%
store_sales.groupby('p1_promo').p1_price.value_counts().unstack() # reshapes DataFrame, making one of the levels of the index into a new column level
# Out:
# p1_price  2.19  2.29  2.49  2.79  2.99
# p1_promo
# 0          371   380   378   371   371
# 1           46    40    38    41    44

# %%
store_sales.groupby(['p1_promo', 'country']).p1_price.mean().unstack()

# %%
p1_table_1 = store_sales.groupby('p1_promo').p1_price.value_counts()
p1_table_1 = p1_table_1.unstack()
p1_table_1.div(p1_table_0)

# %% [markdown]
# ### Continuous Variables

# %%
store_sales.p2_sales.describe()
# Out:
# count    2080.000000
# mean       99.911058
# std        24.453788
# min        51.000000
# 25%        82.000000
# 50%        96.000000
# 75%       115.000000
# max       210.000000
# Name: p2_sales, dtype: float64

# %%
store_sales.p2_sales.min()
# Out:
# 51.0

# %%
store_sales.p1_sales.max()
# Out:
# 265.0

# %%
store_sales.p2_sales.mean()
# Out:
# 99.9110576923077

# %%
store_sales.p2_sales.median()
# Out:
# 96.0

# %%
store_sales.p1_sales.var()
# Out:
# 861.7204626392125

# %%
store_sales.p1_sales.std()
# Out:
# 29.355075585649793

# %%
store_sales.p1_sales.quantile(q=[0.25, 0.5, 0.75])

# %% [markdown]
# ## Single Variable Visualization

# %% [markdown]
# ### Histograms

# %%
store_sales.p2_sales.hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
store_sales.p1_sales.hist()
plt.title('Product 1 weekly sales frequencies, All stores')
plt.xlabel('Product 1 sales (units)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Box plots

# %%
p = store_sales.p2_sales.plot.box(vert=False, sym='k.')
plt.title('Weekly sales of P2, All stores')
plt.xlabel('Weekly sales')
p.set_facecolor('w')

# %%
store_sales.boxplot(column='p2_sales', by='store_num', vert=False, sym='k.')
plt.suptitle('')
plt.title('Weekly sales of p2 by store')
plt.xlabel('Weekly unit sales')
plt.ylabel('Store')
plt.box(False)

# %%
store_sales.boxplot(column='p2_sales', by='p2_promo', vert=False,sym='k.')
plt.suptitle('')
plt.title('Weekly sales of p2 with and without promotion')
plt.xlabel('Weekly unit sales')
plt.ylabel('P2 promo in store?')
plt.yticks([1, 2], ['No', 'Yes'])
plt.box(False)

# %%
plt.scatter(x=store_sales['p1_promo'], y=store_sales['p1_sales'])
plt.show()
